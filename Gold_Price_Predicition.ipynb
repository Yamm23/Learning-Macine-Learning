# %% [markdown]
# <a href="https://colab.research.google.com/github/Yamm23/Gold-Prediction-ML-/blob/main/Gold_Price_Predicition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/LearningAI_CSV/GoldPrice/FINAL_USO.csv')
df = data[['Open','High','Low','Volume','Close']]

# %%
X = df[['Open','High','Low','Volume']]
y = df['Close']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
df.shape
# Out:
# (1718, 5)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train.values,y_train.values)
# Out:
# LinearRegression()

# %%
prediction = model.predict(X_test.values)
prediction
# Out:
# array([117.17254548, 122.27012739, 123.2100709 , 119.22323841,
#        103.6290863 , 119.27598849, 158.48510173, 120.39213394,
#        118.67232282, 127.48294803, 117.11774904, 123.46379138,
#        119.80724166, 115.19418695, 125.1098491 , 118.68084627,
#        118.35873058, 159.72261779, 108.61113595, 118.35101557,
#        108.63483116, 130.35629727, 108.83197804, 118.74082168,
#        128.12116039, 110.56433205, 121.67922041, 118.10076543,
#        126.20322708, 121.84759943, 162.35662299, 126.28550631,
#        124.78809029, 126.75480634, 122.06181204, 171.91882996,
#        113.31798919, 117.92838984, 125.0476788 , 126.37468753,
#        116.34561812, 156.56694283, 165.81621559, 108.46069623,
#        127.62347323, 115.17876801, 121.84883481, 130.45207436,
#        120.30651943, 115.19164032, 152.72924811, 125.97543782,
#        112.10327271, 127.76500114, 117.37168645, 132.01020589,
#        128.14647181, 122.12683572, 121.21108183, 113.39363215,
# ...

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(prediction,y_test)
mae
# Out:
# 0.23227443316332547

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(prediction,y_test)
mse
# Out:
# 0.12195203868709437

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,prediction)
r2
# Out:
# 0.9995785811771761

# %%
import numpy as np
new_data = np.array([[302.74,305.5,303.71,18190]])
prediction = model.predict(new_data)
prediction
# Out:
# array([306.07980154])
