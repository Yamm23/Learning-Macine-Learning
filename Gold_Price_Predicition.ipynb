# %% [markdown]
# <a href="https://colab.research.google.com/github/Yamm23/Learning-Macine-Learning/blob/main/Gold_Price_Predicition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/LearningAI_CSV/GoldPrice/FINAL_USO.csv')
df = data[['Open','High','Low','Volume','Close']]

# %%
X = df[['Open','High','Low','Volume']]
y = df['Close']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
df.shape
# Out:
# (1718, 5)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train.values,y_train.values)
# Out:
# LinearRegression()

# %%
prediction = model.predict(X_test.values)
prediction
# Out:
# array([109.88011101, 128.02425797, 155.53975322, 120.73173633,
#        125.09425456, 113.20234416, 125.49429882, 119.43045089,
#        125.7166284 , 123.54113583, 125.27159111, 118.91609603,
#        123.89059543, 121.54606794, 114.67178545, 121.91770757,
#        116.51514606, 105.60098089, 120.01840931, 168.51234861,
#        172.52454768, 106.20016465, 161.10656967, 122.15379172,
#        117.45629865, 113.60083475, 117.85219782, 166.13306247,
#        128.74514975, 152.70478204, 164.50850291, 126.74046502,
#        116.78270168, 112.09965235, 122.95867239, 122.32111622,
#        119.26324816, 128.29286244, 123.21642271, 157.28698888,
#        120.6197718 , 117.89581726, 111.60253135, 109.05965254,
#        162.444979  , 111.70198221, 152.55621829, 122.11261545,
#        159.84286255, 142.06231553, 128.57514197, 173.70197892,
#        156.31686344, 110.9612342 , 155.08235219, 112.17757261,
#        123.92887685, 160.92991429, 162.33189226, 127.6131608 ,
# ...

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(prediction,y_test)
mae
# Out:
# 0.22525445416099957

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(prediction,y_test)
mse
# Out:
# 0.09865556514044296

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,prediction)
r2
# Out:
# 0.9996859979696919

# %%
import numpy as np
new_data = np.array([[302.74,305.5,303.71,18190]])
prediction = model.predict(new_data)
prediction
# Out:
# array([305.99926938])

# %%
import joblib
joblib.dump(model, 'model.pkl')
model = joblib.load('model.pkl')

# %%
import numpy as np
model = joblib.load('model.pkl')
new_data = np.array([[302.74,305.5,303.71,18190]])
predictions = model.predict(new_data)
print(predictions)
# Out:
# [305.99926938]
